# %%
# %run $main.ipynb
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier

#dataRule = {'dataRules': [0, 1, 2, 3]}
#datas = main(1, dataRule)

datas = main(pr=0)
print(datas)
# Out:
#       gender  seniorCitizen partner dependents  tenure phoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          multipleLines internetService onlineSecurity onlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      deviceProtection techSupport streamingTV streamingMovies  contract  \
# 0                  No          No          No              No         1
# 1                 Yes          No          No              No        12
# 2                  No          No          No              No         1
# 3                 Yes         Yes          No              No        12
# 4                  No          No          No              No         1
# ...               ...         ...         ...             ...       ...
# 7038              Yes         Yes         Yes             Yes        12
# 7039              Yes          No         Yes             Yes        12
# 7040               No          No          No              No         1
# 7041               No          No          No              No         1
# 7042              Yes         Yes         Yes             Yes        24
#
#      paperlessBilling              paymentMethod  monthlyCharges totalCharges  \
# 0                 Yes           Electronic check           29.85        29.85
# 1                  No               Mailed check           56.95       1889.5
# 2                 Yes               Mailed check           53.85       108.15
# 3                  No  Bank transfer (automatic)           42.30      1840.75
# 4                 Yes           Electronic check           70.70       151.65
# ...               ...                        ...             ...          ...
# 7038              Yes               Mailed check           84.80       1990.5
# 7039              Yes    Credit card (automatic)          103.20       7362.9
# 7040              Yes           Electronic check           29.60       346.45
# 7041              Yes               Mailed check           74.40        306.6
# 7042              Yes  Bank transfer (automatic)          105.65       6844.5
#
#      churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 20 columns]
# C:\Users\pedro.b.g.neto\AppData\Local\Temp\ipykernel_8784\3193791170.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataSet['contract'] = dataSet['contract'].replace(time, value)

# %%
for i in datas:
    print(f"{datas[i].value_counts()}\n{datas[i].shape}\n{'*'*20}")
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
# (7043,)
# ********************
# seniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64
# (7043,)
# ********************
# partner
# No     3641
# Yes    3402
# Name: count, dtype: int64
# (7043,)
# ********************
# dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64
# (7043,)
# ********************
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: count, Length: 73, dtype: int64
# (7043,)
# ********************
# phoneService
# Yes    6361
# No      682
# Name: count, dtype: int64
# (7043,)
# ********************
# multipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64
# (7043,)
# ********************
# internetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64
# (7043,)
# ********************
# onlineSecurity
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: count, dtype: int64
# (7043,)
# ********************
# onlineBackup
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: count, dtype: int64
# (7043,)
# ********************
# deviceProtection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64
# (7043,)
# ********************
# techSupport
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64
# (7043,)
# ********************
# streamingTV
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: count, dtype: int64
# (7043,)
# ********************
# streamingMovies
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: count, dtype: int64
# (7043,)
# ********************
# contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64
# (7043,)
# ********************
# paperlessBilling
# Yes    4171
# No     2872
# Name: count, dtype: int64
# (7043,)
# ********************
# paymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64
# (7043,)
# ********************
# monthlyCharges
# 20.05     61
# 19.85     45
# 19.95     44
# 19.90     44
# 20.00     43
#           ..
# 56.85      1
# 101.70     1
# 48.40      1
# 108.35     1
# 72.00      1
# Name: count, Length: 1585, dtype: int64
# (7043,)
# ********************
# totalCharges
# 20.2      11
#           11
# 19.75      9
# 19.65      8
# 19.9       8
#           ..
# 1990.5     1
# 7362.9     1
# 346.45     1
# 306.6      1
# 108.15     1
# Name: count, Length: 6531, dtype: int64
# (7043,)
# ********************
# churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
# (7043,)
# ********************

# %%
print(datas.head(datas.shape[0]-500))

# %%
print(datas.iloc[:-500,-1].values)

# %%
mlp = MLPClassifier(hidden_layer_sizes=(5,), activation="logistic", max_iter=100, alpha=.001, solver="sgd", tol=1e-9, learning_rate_init=.01, 
                    verbose=True)
mlp = mlp.fit(datas.head(datas.shape[0]-500), datas.iloc[:-500,-1].values)

# %%
mlp.predict(datas.tail(500))
