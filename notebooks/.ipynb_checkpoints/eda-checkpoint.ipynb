# %%
# EDA without any data modification

import matplotlib.pyplot as plt
import seaborn as sns
# %run main.ipynb

sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (8, 6)
dataSet = main()

print(dataSet)
# Out:
#       gender  seniorCitizen partner dependents  tenure phoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          multipleLines internetService onlineSecurity onlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
# Churn ditribution
plt.figure()
sns.countplot(x='churn', data=dataSet)
plt.title('Churn distribution')
plt.show()

# Churn rate
churnGeneralRate = dataSet['churn'].value_counts(normalize=True)
print("\nChurn rate proportion:")
print(churnGeneralRate)
# Out:
# Churn rate proportion:
# churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
# Churn analysis by numerical columns
numCols = ['tenure', 'monthlyCharges', 'totalCharges']
for col in numCols:
    plt.figure()
    sns.histplot(data=dataSet, x=col, bins=40, kde=True, hue='churn', element='step')
    plt.title(f'{col} by Churn')
    plt.show()

    print(f"{'-'*120}")
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------

# %%
# Churn analysis by categorical columns
catCols = ['gender', 'seniorCitizen', 'partner', 'dependents',
            'phoneService', 'multipleLines', 'internetService',
            'onlineSecurity', 'onlineBackup', 'deviceProtection',
            'techSupport', 'streamingTV', 'streamingMovies',
            'contract', 'paperlessBilling', 'paymentMethod']

for col in catCols:
    # Chart setting
    plt.figure()
    sns.countplot(x=col, hue='churn', data=dataSet)
    plt.tight_layout()
    plt.show()

    # Churn rate by group
    churnGroupRate = dataSet.groupby(col)['churn'].value_counts(normalize=True).unstack()
    print(churnGroupRate)

    # Churn rate 'Yes' by group
    if 'Yes' in churnGroupRate.columns:
        churnRate = churnGroupRate['Yes'].sort_values(ascending=False)
        print(f"\nChurn by {col}")
        print(churnRate.head())

    print(f"{'-'*120}")
# Out:
# churn         No       Yes
# gender
# Female  0.730791  0.269209
# Male    0.738397  0.261603
#
# Churn by gender
# gender
# Female    0.269209
# Male      0.261603
# Name: Yes, dtype: float64
# ------------------------------------------------------------------------------------------------------------------------
# churn                No       Yes
# seniorCitizen
# 0              0.763938  0.236062
# 1              0.583187  0.416813
#
# Churn by seniorCitizen
# seniorCitizen
# 1    0.416813
# 0    0.236062
# Name: Yes, dtype: float64
# ------------------------------------------------------------------------------------------------------------------------
# churn          No       Yes
# partner
# No       0.670420  0.329580
# Yes      0.803351  0.196649
#
# Churn by partner
# partner
# No     0.329580
# Yes    0.196649
# Name: Yes, dtype: float64
# ------------------------------------------------------------------------------------------------------------------------
# ...
