# %%
# default dataset file = "dataset_tcc_churn_0-1.csv" 
# default dataset subpath = "dataset_tcc_churn_0-1.csv" 
def main(pr=1, file="dataset_tcc_churn_0-1.csv", path="../datasets/telco-customer-churn/versions/1/"):
    try:
        # %run _dataProcessing.ipynb
        # %run _dataProcessing2.ipynb
        # %run $rename.ipynb
        # %run $impData.ipynb
        
        dataSet = impData(pr, file, path)
        rename(dataSet, pr)
        dataSet1 = dataProcessing(dataSet, pr)
        dataSet2 = dataProcessing2(dataSet, pr)

        dataSet = dataSet2
        
        if pr:
            print(f"Dataset {file} imported!\n{'*'*20}")
            
    except Exception as e:
        print(f"Error importing {file}. {e}")

    return dataSet
