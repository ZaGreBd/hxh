# %%
# Params
testSize = 0.2
scaler = "mm"

# Decision Tree Results
# %run cla_dt.ipynb
print(f"\n{'='*49}DECISION TREE RESULTS{'='*50}\n")
dt(testSize, scaler)

# Support Vector Machine (SVM) Results
# %run cla_svm.ipynb
print(f"\n{'='*54}SVM RESULTS{'='*55}\n")
svm(testSize, scaler)

# Multilayer Perceptron (MLP) Results
# %run cla_mlp.ipynb
print(f"\n{'='*54}MLP RESULTS{'='*55}\n")
mlp(testSize, scaler)
# Out:
# =================================================DECISION TREE RESULTS==================================================
#
# Decision Tree
# Best Params: {'max_depth': 4}
# [[929 107]
#  [172 201]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1036
#            1       0.65      0.54      0.59       373
#
#     accuracy                           0.80      1409
#    macro avg       0.75      0.72      0.73      1409
# weighted avg       0.79      0.80      0.80      1409
#
# ROC-AUC: 0.7177960706781084
#
# ======================================================SVM RESULTS=======================================================
#
# Support Vector Machine
# Best Params: {'C': 18.5, 'kernel': 'rbf'}
# [[946  90]
#  [181 192]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      1036
#            1       0.68      0.51      0.59       373
#
#     accuracy                           0.81      1409
#    macro avg       0.76      0.71      0.73      1409
# weighted avg       0.80      0.81      0.80      1409
#
# ROC-AUC: 0.7139363607192025
#
# ======================================================MLP RESULTS=======================================================
#
# Multilayer Perceptron
# Best Params: {'activation': 'relu', 'alpha': 0.0002, 'hidden_layer_sizes': (10, 1), 'learning_rate_init': 0.001, 'max_iter': 1000, 'solver': 'adam', 'tol': 1e-07}
# [[931 105]
#  [159 214]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88      1036
#            1       0.67      0.57      0.62       373
#
#     accuracy                           0.81      1409
#    macro avg       0.76      0.74      0.75      1409
# weighted avg       0.81      0.81      0.81      1409
#
# ROC-AUC: 0.7361875951018042

# %%
# Params
testSize = 0.2
scaler = "ss"

# Decision Tree Results
# %run cla_dt.ipynb
print(f"\n{'='*49}DECISION TREE RESULTS{'='*50}\n")
dt(testSize, scaler)

# Support Vector Machine (SVM) Results
# %run cla_svm.ipynb
print(f"\n{'='*54}SVM RESULTS{'='*55}\n")
svm(testSize, scaler)

# Multilayer Perceptron (MLP) Results
# %run cla_mlp.ipynb
print(f"\n{'='*54}MLP RESULTS{'='*55}\n")
mlp(testSize, scaler)
# Out:
# =================================================DECISION TREE RESULTS==================================================
#
# Decision Tree
# Best Params: {'max_depth': 4}
# [[929 107]
#  [172 201]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1036
#            1       0.65      0.54      0.59       373
#
#     accuracy                           0.80      1409
#    macro avg       0.75      0.72      0.73      1409
# weighted avg       0.79      0.80      0.80      1409
#
# ROC-AUC: 0.7177960706781084
#
# ======================================================SVM RESULTS=======================================================
#
# Support Vector Machine
# Best Params: {'C': 18.5, 'kernel': 'rbf'}
# [[946  90]
#  [181 192]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      1036
#            1       0.68      0.51      0.59       373
#
#     accuracy                           0.81      1409
#    macro avg       0.76      0.71      0.73      1409
# weighted avg       0.80      0.81      0.80      1409
#
# ROC-AUC: 0.7139363607192025
#
# ======================================================MLP RESULTS=======================================================
#
# Multilayer Perceptron
# Best Params: {'activation': 'relu', 'alpha': 0.0002, 'hidden_layer_sizes': (10, 1), 'learning_rate_init': 0.001, 'max_iter': 1000, 'solver': 'adam', 'tol': 1e-07}
# [[931 105]
#  [159 214]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88      1036
#            1       0.67      0.57      0.62       373
#
#     accuracy                           0.81      1409
#    macro avg       0.76      0.74      0.75      1409
# weighted avg       0.81      0.81      0.81      1409
#
# ROC-AUC: 0.7361875951018042
